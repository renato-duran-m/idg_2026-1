# %%
# !pip install statsmodels
import numpy as np
import pandas as pd
import geopandas as gpd
import pyreadr
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn.metrics import roc_auc_score, roc_curve
from ipfn import ipfn
# Out:
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB 93.9 kB/s eta 0:01:42
#    ---------------------------------------- 0.0/9.6 MB 119.8 kB/s eta 0:01:20
#    ---------------------------------------- 0.0/9.6 MB 140.9 kB/s eta 0:01:08
#    ---------------------------------------- 0.0/9.6 MB 140.9 kB/s eta 0:01:08
#    ---------------------------------------- 0.1/9.6 MB 156.1 kB/s eta 0:01:01
#    ---------------------------------------- 0.1/9.6 MB 187.3 kB/s eta 0:00:51
#    ---------------------------------------- 0.1/9.6 MB 227.0 kB/s eta 0:00:42
#     --------------------------------------- 0.1/9.6 MB 257.8 kB/s eta 0:00:37
# ...

# %%
RUTA_CENSO_ZONAL = "../Parquet/Cartografía_censo2024_R13_Zonal.parquet"
RUTA_CASEN = "../Parquet/casen_rm.rds"
RUTA_EPF_PERSONAS = "../EPF/base-personas-ix-epf-stata.dta"
RUTA_EPF_CANTIDADES = "../EPF/base-cantidades-ix-epf-stata.dta"

SEED=123
