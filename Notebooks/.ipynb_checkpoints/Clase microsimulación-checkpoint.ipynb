# %% [markdown]
# ## CLASE DE MICROSIMULACIÓN

# %%
import geopandas as gpd
# !conda install -y pyarrow
# Out:
# Jupyter detected...
# 3 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - defaults
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\DIGEA\anaconda3\envs\idg
#
#   added / updated specs:
#     - pyarrow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     arrow-cpp-23.0.1           |   cpu_he67cb5a_4         7.1 MB
#     aws-c-auth-0.10.1          |       h1c6eee0_0         120 KB
#     aws-c-cal-0.9.13           |       h630b2a1_0          58 KB
#     aws-c-common-0.12.6        |       h02ab6af_0         238 KB
#     aws-c-compression-0.3.2    |       h1c6eee0_0          29 KB
#     aws-c-event-stream-0.6.1   |       h1c6eee0_0          61 KB
#     aws-c-http-0.10.13         |       h1c6eee0_0         197 KB
#     aws-c-io-0.26.3            |       h1c6eee0_0         173 KB
#     aws-c-mqtt-0.15.2          |       h1c6eee0_0         202 KB
#     aws-c-s3-0.12.0            |       h1c6eee0_1         133 KB
#     aws-c-sdkutils-0.2.4       |       h02ab6af_2          60 KB
#     aws-checksums-0.2.10       |       h1c6eee0_0         122 KB
#     aws-crt-cpp-0.37.4         |       hd7fb8db_1         331 KB
#     aws-sdk-cpp-1.11.774       |       hbc24388_1        19.3 MB
#     c-ares-1.34.7              |       h2c209ce_0         200 KB
#     certifi-2026.6.17          |  py313haa95532_0         131 KB
#     gflags-2.3.0               |       h8074b40_0         217 KB
#     glog-0.7.1                 |       h5c3225e_0         120 KB
#     libabseil-20260107.0       | cxx17_hc587421_0         1.8 MB
#     libbrotlicommon-1.2.0      |       h907acca_0          86 KB
#     libbrotlidec-1.2.0         |       h02c67a5_0          39 KB
#     libbrotlienc-1.2.0         |       h483e6b9_0         253 KB
#     libcurl-8.20.0             |       h9440e04_1         440 KB
#     libgrpc-1.78.0             |       h1618ae7_1        11.2 MB
#     libkrb5-1.22.2             |       h3d06f0e_0         677 KB
#     libprotobuf-6.33.5         |       h65d7223_0         6.9 MB
#     libre2-11-2025.11.05       |       h797e85b_1         266 KB
#     lz4-c-1.9.4                |       h1c6eee0_5         129 KB
#     openssl-3.5.7              |       hbb43b14_0         8.9 MB
#     orc-2.2.0                  |       h1e45922_2         1.0 MB
#     pyarrow-23.0.1             |cpu_py313h1c66dc0_3         4.6 MB
#     re2-2025.11.05             |       hca2749c_1         214 KB
#     snappy-1.2.2               |       hab6b7b3_1          96 KB
#     ------------------------------------------------------------
#                                            Total:        65.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   arrow-cpp          pkgs/main/win-64::arrow-cpp-23.0.1-cpu_he67cb5a_4
#   aws-c-auth         pkgs/main/win-64::aws-c-auth-0.10.1-h1c6eee0_0
#   aws-c-cal          pkgs/main/win-64::aws-c-cal-0.9.13-h630b2a1_0
#   aws-c-common       pkgs/main/win-64::aws-c-common-0.12.6-h02ab6af_0
#   aws-c-compression  pkgs/main/win-64::aws-c-compression-0.3.2-h1c6eee0_0
#   aws-c-event-stream pkgs/main/win-64::aws-c-event-stream-0.6.1-h1c6eee0_0
#   aws-c-http         pkgs/main/win-64::aws-c-http-0.10.13-h1c6eee0_0
#   aws-c-io           pkgs/main/win-64::aws-c-io-0.26.3-h1c6eee0_0
#   aws-c-mqtt         pkgs/main/win-64::aws-c-mqtt-0.15.2-h1c6eee0_0
#   aws-c-s3           pkgs/main/win-64::aws-c-s3-0.12.0-h1c6eee0_1
#   aws-c-sdkutils     pkgs/main/win-64::aws-c-sdkutils-0.2.4-h02ab6af_2
#   aws-checksums      pkgs/main/win-64::aws-checksums-0.2.10-h1c6eee0_0
#   aws-crt-cpp        pkgs/main/win-64::aws-crt-cpp-0.37.4-hd7fb8db_1
#   aws-sdk-cpp        pkgs/main/win-64::aws-sdk-cpp-1.11.774-hbc24388_1
#   c-ares             pkgs/main/win-64::c-ares-1.34.7-h2c209ce_0
#   gflags             pkgs/main/win-64::gflags-2.3.0-h8074b40_0
#   glog               pkgs/main/win-64::glog-0.7.1-h5c3225e_0
#   libabseil          pkgs/main/win-64::libabseil-20260107.0-cxx17_hc587421_0
#   libbrotlicommon    pkgs/main/win-64::libbrotlicommon-1.2.0-h907acca_0
#   libbrotlidec       pkgs/main/win-64::libbrotlidec-1.2.0-h02c67a5_0
#   libbrotlienc       pkgs/main/win-64::libbrotlienc-1.2.0-h483e6b9_0
#   libcurl            pkgs/main/win-64::libcurl-8.20.0-h9440e04_1
#   libgrpc            pkgs/main/win-64::libgrpc-1.78.0-h1618ae7_1
#   libkrb5            pkgs/main/win-64::libkrb5-1.22.2-h3d06f0e_0
#   libprotobuf        pkgs/main/win-64::libprotobuf-6.33.5-h65d7223_0
#   libre2-11          pkgs/main/win-64::libre2-11-2025.11.05-h797e85b_1
#   libssh2            pkgs/main/win-64::libssh2-1.11.1-h2addb87_0
#   libthrift          pkgs/main/win-64::libthrift-0.22.0-ha2884a9_0
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.4-h1c6eee0_5
#   orc                pkgs/main/win-64::orc-2.2.0-h1e45922_2
#   pyarrow            pkgs/main/win-64::pyarrow-23.0.1-cpu_py313h1c66dc0_3
#   re2                pkgs/main/win-64::re2-2025.11.05-hca2749c_1
#   snappy             pkgs/main/win-64::snappy-1.2.2-hab6b7b3_1
#   utf8proc           pkgs/main/win-64::utf8proc-2.6.1-h2bbff1b_1
#   zstd               pkgs/main/win-64::zstd-1.5.7-h56299aa_0
#
# The following packages will be UPDATED:
#
#   certifi                         2026.5.20-py313haa95532_0 --> 2026.6.17-py313haa95532_0
#   openssl                                  3.5.6-hbb43b14_0 --> 3.5.7-hbb43b14_0
#
#
#
# Downloading and Extracting Packages: ...working...
# aws-sdk-cpp-1.11.774 | 19.3 MB   |            |   0%
#
# libgrpc-1.78.0       | 11.2 MB   |            |   0%
#
#
# openssl-3.5.7        | 8.9 MB    |            |   0%
#
#
#
# arrow-cpp-23.0.1     | 7.1 MB    |            |   0%
#
#
#
#
# libprotobuf-6.33.5   | 6.9 MB    |            |   0%
#
#
#
#
#
# pyarrow-23.0.1       | 4.6 MB    |            |   0%
#
#
#
#
#
#
# libabseil-20260107.0 | 1.8 MB    |            |   0%
#
#
#
#
#
#
#
# orc-2.2.0            | 1.0 MB    |            |   0%
#
#
#
#
#
#
#
#
# libkrb5-1.22.2       | 677 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# libcurl-8.20.0       | 440 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.37.4   | 331 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# libre2-11-2025.11.05 | 266 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.2.0   | 253 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.12.6  | 238 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gflags-2.3.0         | 217 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2025.11.05       | 214 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-mqtt-0.15.2    | 202 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.34.7        | 200 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.10.13   | 197 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# aws-sdk-cpp-1.11.774 | 19.3 MB   | ##         |  20%
#
#
# openssl-3.5.7        | 8.9 MB    |            |   1%
#
#
#
# arrow-cpp-23.0.1     | 7.1 MB    | 4          |   4%
#
# libgrpc-1.78.0       | 11.2 MB   | 5          |   5%
#
#
#
#
# libprotobuf-6.33.5   | 6.9 MB    | 4          |   5%
# aws-sdk-cpp-1.11.774 | 19.3 MB   | #####4     |  55%
#
#
#
# arrow-cpp-23.0.1     | 7.1 MB    | #8         |  19%
#
#
#
#
# libprotobuf-6.33.5   | 6.9 MB    | #5         |  15%
#
# libgrpc-1.78.0       | 11.2 MB   | #6         |  17%
#
#
# openssl-3.5.7        | 8.9 MB    | #1         |  12%
# aws-sdk-cpp-1.11.774 | 19.3 MB   | ########4  |  85%
#
#
#
# arrow-cpp-23.0.1     | 7.1 MB    | ####2      |  43%
#
# libgrpc-1.78.0       | 11.2 MB   | ##8        |  28%
#
#
# openssl-3.5.7        | 8.9 MB    | ###        |  31%
#
#
#
#
# libprotobuf-6.33.5   | 6.9 MB    | ##6        |  27%
# aws-sdk-cpp-1.11.774 | 19.3 MB   | ########## | 100%
#
#
#
#
#
# pyarrow-23.0.1       | 4.6 MB    |            |   0%
#
#
#
# arrow-cpp-23.0.1     | 7.1 MB    | ########5  |  85%
#
# libgrpc-1.78.0       | 11.2 MB   | ###7       |  38%
#
#
# openssl-3.5.7        | 8.9 MB    | ######2    |  63%
#
#
#
#
# libprotobuf-6.33.5   | 6.9 MB    | ###9       |  39%
#
#
#
#
#
# pyarrow-23.0.1       | 4.6 MB    | #######8   |  79%
#
#
#
# arrow-cpp-23.0.1     | 7.1 MB    | ########## | 100%
#
#
#
#
# libprotobuf-6.33.5   | 6.9 MB    | #####2     |  53%
#
#
#
#
#
#
# libabseil-20260107.0 | 1.8 MB    |            |   1%
#
#
#
#
#
# pyarrow-23.0.1       | 4.6 MB    | ########## | 100%
#
#
#
#
#
#
#
# orc-2.2.0            | 1.0 MB    | 1          |   2%
#
# libgrpc-1.78.0       | 11.2 MB   | ####7      |  47%
#
#
#
#
#
#
#
# orc-2.2.0            | 1.0 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# libkrb5-1.22.2       | 677 KB    | 2          |   2%
#
#
#
#
#
#
# libabseil-20260107.0 | 1.8 MB    | #######3   |  74%
#
#
# openssl-3.5.7        | 8.9 MB    | ########## | 100%
#
#
# openssl-3.5.7        | 8.9 MB    | ########## | 100%
#
# libgrpc-1.78.0       | 11.2 MB   | ######2    |  62%
#
#
#
#
#
#
#
#
# libkrb5-1.22.2       | 677 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libcurl-8.20.0       | 440 KB    | 3          |   4%
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.37.4   | 331 KB    | 4          |   5%
#
#
#
#
#
#
# libabseil-20260107.0 | 1.8 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.37.4   | 331 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libcurl-8.20.0       | 440 KB    | ########## | 100%
#
#
#
#
# libprotobuf-6.33.5   | 6.9 MB    | ########## | 100%
#
#
#
#
# libprotobuf-6.33.5   | 6.9 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# libre2-11-2025.11.05 | 266 KB    | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.2.0   | 253 KB    | 6          |   6%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gflags-2.3.0         | 217 KB    | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.12.6  | 238 KB    | 6          |   7%
#
#
#
#
#
#
#
#
#
#
#
# libre2-11-2025.11.05 | 266 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.2.0   | 253 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.12.6  | 238 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gflags-2.3.0         | 217 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2025.11.05       | 214 KB    | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-mqtt-0.15.2    | 202 KB    | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-mqtt-0.15.2    | 202 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.10.13   | 197 KB    | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.34.7        | 200 KB    | 8          |   8%
#
# libgrpc-1.78.0       | 11.2 MB   | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2025.11.05       | 214 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.10.13   | 197 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.34.7        | 200 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libgrpc-1.78.0       | 11.2 MB   | ########3  |  83%
#
# libgrpc-1.78.0       | 11.2 MB   | ########## | 100%
#
# libgrpc-1.78.0       | 11.2 MB   | ########## | 100%
#
#
#
# arrow-cpp-23.0.1     | 7.1 MB    | ########## | 100%
#
#
#
#
#
#
#
# orc-2.2.0            | 1.0 MB    | ########## | 100%
#
#
#
#
#
#
#
# orc-2.2.0            | 1.0 MB    | ########## | 100%
#
#
#
#
#
# pyarrow-23.0.1       | 4.6 MB    | ########## | 100%
#
#
#
#
#
#
#
#
# libkrb5-1.22.2       | 677 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# libkrb5-1.22.2       | 677 KB    | ########## | 100%
#
#
# openssl-3.5.7        | 8.9 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.37.4   | 331 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# aws-crt-cpp-0.37.4   | 331 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libcurl-8.20.0       | 440 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libcurl-8.20.0       | 440 KB    | ########## | 100%
#
#
#
#
#
#
# libabseil-20260107.0 | 1.8 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# libre2-11-2025.11.05 | 266 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# libre2-11-2025.11.05 | 266 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.2.0   | 253 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlienc-1.2.0   | 253 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.12.6  | 238 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-common-0.12.6  | 238 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gflags-2.3.0         | 217 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# gflags-2.3.0         | 217 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-mqtt-0.15.2    | 202 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-mqtt-0.15.2    | 202 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2025.11.05       | 214 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# re2-2025.11.05       | 214 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.10.13   | 197 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# aws-c-http-0.10.13   | 197 KB    | ########## | 100%
#
#
#
#
# libprotobuf-6.33.5   | 6.9 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.34.7        | 200 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# c-ares-1.34.7        | 200 KB    | ########## | 100%
# aws-sdk-cpp-1.11.774 | 19.3 MB   | ########## | 100%
#
# libgrpc-1.78.0       | 11.2 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Channel "defaults" has the following notices:
#   [info] -- Tue Jun  9 00:00:00 2026
#   PyTorch 2.12 with CUDA support is now available to install with your current channel (Anaconda Main). Learn more: https://anaconda.org/main/pytorch?utm_source=channel_notices
# ==> WARNING: A newer version of conda exists. <==
#     current version: 26.1.1
#     latest version: 26.5.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
RUTA_CENSO_ZONAL = "../Parquet/Cartografía_censo2024_R13_Zonal.parquet"

# %% [markdown]
# ## Entradas

# %%
censo_zonal = gpd.read_parquet(RUTA_CENSO_ZONAL)

# %%
censo_zonal
# Out:
#       OBJECTID    CUT  COD_REGION                     REGION  COD_PROVINCIA  \
# 0         2663  13402          13  METROPOLITANA DE SANTIAGO            134
# 1         2664  13402          13  METROPOLITANA DE SANTIAGO            134
# 2         2665  13402          13  METROPOLITANA DE SANTIAGO            134
# 3         2666  13402          13  METROPOLITANA DE SANTIAGO            134
# 4         2667  13402          13  METROPOLITANA DE SANTIAGO            134
# ...        ...    ...         ...                        ...            ...
# 1860      4524  13504          13  METROPOLITANA DE SANTIAGO            135
# 1861      4525  13504          13  METROPOLITANA DE SANTIAGO            135
# 1862      4526  13118          13  METROPOLITANA DE SANTIAGO            131
# 1863      4902  13120          13  METROPOLITANA DE SANTIAGO            131
# 1864      4909  13120          13  METROPOLITANA DE SANTIAGO            131
#
#       PROVINCIA       COMUNA  AREA_C           DISTRITO  COD_DISTRITO  ...  \
# 0         MAIPO         BUIN  URBANO         EL RECURSO             6  ...
# 1         MAIPO         BUIN  URBANO        ALTO JAHUEL             2  ...
# 2         MAIPO         BUIN  URBANO  VALDIVIA DE PAINE             5  ...
# 3         MAIPO         BUIN  URBANO  VALDIVIA DE PAINE             5  ...
# 4         MAIPO         BUIN  URBANO               BUIN             1  ...
# ...         ...          ...     ...                ...           ...  ...
# 1860  MELIPILLA  MARÍA PINTO  URBANO           IBACACHE             4  ...
# 1861  MELIPILLA  MARÍA PINTO  URBANO          LO OVALLE             2  ...
# 1862   SANTIAGO        MACUL  URBANO    CAMINO AGRÍCOLA             4  ...
# 1863   SANTIAGO        ÑUÑOA  URBANO   ESTADIO NACIONAL             8  ...
# 1864   SANTIAGO        ÑUÑOA  URBANO      PLAZA ZAÑARTU             7  ...
#
#       n_fuente_elect_otro  n_fuente_elect_no_tiene n_basura_servicios  \
# 0                     4.0                      1.0              704.0
# 1                     1.0                      0.0              895.0
# 2                     6.0                      4.0             1338.0
# 3                    10.0                      5.0              811.0
# 4                     0.0                      1.0             1865.0
# ...                   ...                      ...                ...
# 1860                  0.0                      2.0              350.0
# 1861                  0.0                      0.0              310.0
# 1862                  0.0                      1.0             1023.0
# 1863                  1.0                      1.0              837.0
# 1864                  0.0                      0.0             1263.0
#
#       n_basura_entierra n_basura_eriazo  n_basura_rio n_basura_otro  \
# 0                   3.0             0.0           0.0           4.0
# 1                   0.0             1.0           0.0           2.0
# 2                   2.0             1.0           0.0           1.0
# 3                   0.0             0.0           0.0           1.0
# 4                   1.0             0.0           0.0           1.0
# ...                 ...             ...           ...           ...
# 1860                3.0             0.0           0.0           0.0
# 1861                0.0             0.0           0.0           0.0
# 1862                0.0             0.0           0.0           0.0
# 1863                0.0             0.0           0.0           0.0
# 1864                1.0             0.0           0.0           1.0
#
#       SHAPE_Length  SHAPE_Area  \
# 0         0.085226    0.000076
# 1         0.083812    0.000099
# 2         0.176524    0.000170
# 3         0.063728    0.000153
# 4         0.048323    0.000072
# ...            ...         ...
# 1860      0.114486    0.000096
# 1861      0.030209    0.000033
# 1862      0.052187    0.000065
# 1863      0.053861    0.000098
# 1864      0.027436    0.000019
#
#                                                   SHAPE
# 0     MULTIPOLYGON (((-70.66374 -33.66766, -70.66357...
# 1     MULTIPOLYGON (((-70.68434 -33.73325, -70.68432...
# 2     MULTIPOLYGON (((-70.79271 -33.77484, -70.79476...
# 3     MULTIPOLYGON (((-70.85249 -33.80397, -70.85273...
# 4     MULTIPOLYGON (((-70.74602 -33.70887, -70.74605...
# ...                                                 ...
# 1860  MULTIPOLYGON (((-71.26417 -33.48377, -71.26402...
# 1861  MULTIPOLYGON (((-71.08214 -33.46069, -71.08214...
# 1862  MULTIPOLYGON (((-70.61641 -33.48493, -70.61661...
# 1863  MULTIPOLYGON (((-70.60672 -33.46546, -70.60664...
# 1864  MULTIPOLYGON (((-70.59859 -33.46908, -70.59859...
#
# [1865 rows x 213 columns]
